# %%
import healpy  as hp
import numpy as np
import pylab as plt

# %%
import camb

# %%
par = camb.CAMBparams()
par.set_cosmology(H0=67.5)
res = camb.camb.get_results(par)

# %%
cl = res.get_cmb_power_spectra(raw_cl=True)['total']

# %%
plt.loglog(cl)

# %%
print (cl.shape)
np.random.seed(2)
m = hp.synfast(cl.T, nside=128, new=True)
hp.mollview(m[0])
hp.mollview(m[1])
hp.mollview(m[2])
# Out:
# (2401, 4)
# Sigma is 0.000000 arcmin (0.000000 rad)
# -> fwhm is 0.000000 arcmin

# %%
Ip = (m[1]**2+m[2]**2)**0.5
hp.mollview(Ip)

# %%
cla = hp.anafast(m)

# %%
plt.loglog(cla[:3].T)

# %%
plt.loglog(cl.T[0])
plt.loglog(cla[0])

# %%
par1 = camb.CAMBparams()
par1.set_cosmology(H0=67.5)
par1.InitPower.set_params(As=2e-9, ns=0.3, r=0)
res1 = camb.camb.get_results(par1)
cl1 = res1.get_cmb_power_spectra( raw_cl=True)['total']

# %%
plt.loglog(cl1.T[0])
plt.loglog(cla[0], '*')
